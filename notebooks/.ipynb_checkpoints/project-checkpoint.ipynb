# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import load_model

# %%
# Prepare data file location and load the dataset
data_file_location = "..\\data\\raw\\"
data_file_name = "6758_Stock"
data_file_ext = "csv"

# Load data file
data = pd.read_csv(data_file_location + data_file_name + "." + data_file_ext)

# %%
# Check dataset shape
data.shape
# Out:
# (14455, 9)

# %%
N = 10000  # 设定你想要保留的训练样本数量
data = data.iloc[-N:]  # 选取最后 N 行

# %%
# Check dataset head
data.head()
# Out:
#       Unnamed: 0                       date    open    high     low   close  \
# 4455        4455  2023-10-23 12:35:00+09:00  2492.0  2496.0  2491.0  2495.0
# 4456        4456  2023-10-23 12:40:00+09:00  2496.0  2496.0  2495.0  2495.0
# 4457        4457  2023-10-23 12:45:00+09:00  2495.0  2495.0  2493.0  2494.0
# 4458        4458  2023-10-23 12:50:00+09:00  2494.0  2495.0  2493.0  2493.0
# 4459        4459  2023-10-23 12:55:00+09:00  2493.0  2493.0  2491.0  2493.0
#
#         volume  average  barCount
# 4455  166000.0  2492.98        65
# 4456   76500.0  2495.24        33
# 4457   59000.0  2493.88        38
# 4458   36000.0  2494.06        34
# 4459   56000.0  2492.26        40

# %%
# Check data types
data.dtypes
# Out:
# Unnamed: 0      int64
# date           object
# open          float64
# high          float64
# low           float64
# close         float64
# volume        float64
# average       float64
# barCount        int64
# dtype: object

# %%
# 画出 Time Bar 级别的不同价格曲线
plt.figure(figsize=(12, 6))
time_bar_index = data.index

plt.plot(time_bar_index, data['open'], label='Open', color='red')
plt.plot(time_bar_index, data['high'], label='High', color='orange')
plt.plot(time_bar_index, data['low'], label='Low', color='yellow')
plt.plot(time_bar_index, data['close'], label='Close', color='green')
plt.plot(time_bar_index, data['average'], label='Average', color='blue')

plt.xlabel("Time Bar Index")
plt.ylabel("Price")
plt.title("Different Prices in Time Bar")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Select Independent Features

# %% [markdown]
# The objective of this analysis is to implement a multi-variant prediction, taking into account possible impact of several independent features such as the Open price, Close price and Volume on future stock price performance.
#
# Therefore, in this analysis, we will incorporate all the available variables:
# - Opening price
# - Highest price
# - Lowest price
# - Closing price
# - Trading volume
#
# These features will be utilized to forecast the future opening price.

# %%
# Define selected features and target attribute
features = ["open", "high", "low",	"close", "volume"]
target = "open"

# %%
df = data[features]
df
# Out:
#          open    high     low   close    volume
# 4455   2492.0  2496.0  2491.0  2495.0  166000.0
# 4456   2496.0  2496.0  2495.0  2495.0   76500.0
# 4457   2495.0  2495.0  2493.0  2494.0   59000.0
# 4458   2494.0  2495.0  2493.0  2493.0   36000.0
# 4459   2493.0  2493.0  2491.0  2493.0   56000.0
# ...       ...     ...     ...     ...       ...
# 14450  2788.0  2789.0  2786.0  2787.0   89500.0
# 14451  2786.0  2791.0  2786.0  2790.0  226000.0
# 14452  2791.0  2791.0  2788.0  2789.0  178000.0
# 14453  2789.0  2791.0  2788.0  2790.0  246000.0
# 14454  2790.0  2792.0  2786.0  2786.0  634000.0
#
# [10000 rows x 5 columns]

# %% [markdown]
# #### Create Train, Validation, and Test Datasets

# %%
len_train = int(0.6 * df.shape[0])  # 60% 用作训练集
len_val = int(0.3 * df.shape[0])   # 30% 用作验证集
len_test = df.shape[0] - len_train - len_val  # 剩下的 10% 用作测试集

# 分割训练集
df_train = df[:len_train]

# 分割验证集
df_validate = df[len_train:len_train+len_val]

# 分割测试集
df_test = df[len_train+len_val:]

# 打印每个数据集的形状，确保分割正确
print(f"Train Set Shape: {df_train.shape}")
print(f"Validation Set Shape: {df_validate.shape}")
print(f"Test Set Shape: {df_test.shape}")
# Out:
# Train Set Shape: (6000, 5)
# Validation Set Shape: (3000, 5)
# Test Set Shape: (1000, 5)

# %%
df_train
# Out:
#          open    high     low   close    volume
# 4455   2492.0  2496.0  2491.0  2495.0  166000.0
# 4456   2496.0  2496.0  2495.0  2495.0   76500.0
# 4457   2495.0  2495.0  2493.0  2494.0   59000.0
# 4458   2494.0  2495.0  2493.0  2493.0   36000.0
# 4459   2493.0  2493.0  2491.0  2493.0   56000.0
# ...       ...     ...     ...     ...       ...
# 10450  2626.0  2629.0  2626.0  2627.0  106000.0
# 10451  2627.0  2629.0  2625.0  2628.0   95000.0
# 10452  2627.0  2627.0  2622.0  2622.0  109000.0
# 10453  2623.0  2626.0  2621.0  2626.0  129000.0
# 10454  2625.0  2628.0  2625.0  2627.0   83500.0
#
# [6000 rows x 5 columns]

# %%
# Extract dates from each dataset
df_train_index = df_train.index
df_validate_index = df_validate.index
df_test_index = df_test.index

# %%
# Initialize scaler with range [0,1]
sc = MinMaxScaler(feature_range=(0,1))

# Fit and transform scaler to training set
data_train_scaled = sc.fit_transform(df_train)

# Transform validating and testing datasets
data_validate_scaled = sc.transform(df_validate)
data_test_scaled = sc.transform(df_test)

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data, sequence_size, target_attr_idx):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        data_X.append(data[i-sequence_size:i,0:data.shape[1]])
        data_y.append(data[i,target_attr_idx])
        
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %%
# data_train_scaled = df_train.values
# data_validate_scaled = df_validate.values
# data_test_scaled = df_test.values

# %%
# Define the sequence size
sequence_size = 30

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled, sequence_size, 0)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:], sequence_size, 0)

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:], sequence_size, 0)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (10000, 5)
#
#  Data Train Scaled: (6000, 5)
# > Data Train X: (5999, 1, 5)
# > Data Train y: (5999,)
#
#  Data Validate Scaled: (3000, 5)
# > Data Validate X: (3000, 1, 5)
# > Data Validate y: (3000,)
#
#  Data Test Scaled: (1000, 5)
# > Data Test X: (1000, 1, 5)
# > Data Test y: (1000,)

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()

# Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# Add LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 50, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

regressor.add(LSTM(units = 1))
regressor.add(Dropout(rate = 0.2))

# regressor.add(LSTM(units = 100))
# regressor.add(Dropout(rate = 0.2))

# # Add forth LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 100))
# regressor.add(Dropout(rate = 0.2))

# Add last dense layer/output layer
regressor.add(Dense(units = 1))

# Compiling the model
regressor.compile(optimizer = "adam", loss="mean_squared_error")

# %% [markdown]
# #### Training Model

# %% [markdown]
# EarlyStopping 会在验证集损失停止改善时停止训练，并且可以通过 restore_best_weights=True 恢复最好的模型权重（即训练过程中验证集损失最小的权重）。
# ModelCheckpoint 会保存验证集损失最小的模型，帮助你在训练结束后获得最佳的模型权重。

# %%
# # Define EarlyStopping callback
# early_stopping = EarlyStopping(
#     monitor='val_loss',         # Monitor the validation loss
#     patience=10,                # Stop after 10 epochs with no improvement
#     restore_best_weights=True,  # Restore the best weights from the training process
#     verbose=1
# )

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "sony_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss",             # Monitor validation loss
    save_best_only=True,            # Save only the best model based on validation loss
    mode="min",                     # We want to minimize validation loss
    verbose=0)

# %%
# Training the model with both callbacks
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=200, 
    batch_size=64, 
    callbacks=[best_model_checkpoint_callback]
    # callbacks=[early_stopping, best_model_checkpoint_callback]
)
# Out:
# Epoch 1/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.2341 - val_loss: 0.0335
# Epoch 2/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1240 - val_loss: 0.0118
# Epoch 3/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0634 - val_loss: 0.0166
# Epoch 4/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0179
# Epoch 5/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0305 - val_loss: 0.0130
# Epoch 6/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0229 - val_loss: 0.0085
# Epoch 7/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0186 - val_loss: 0.0054
# Epoch 8/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0154 - val_loss: 0.0040
# Epoch 9/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0136 - val_loss: 0.0032
# Epoch 10/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0121 - val_loss: 0.0030
# Epoch 11/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0114 - val_loss: 0.0029
# Epoch 12/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0120 - val_loss: 0.0031
# Epoch 13/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0101 - val_loss: 0.0032
# Epoch 14/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0103 - val_loss: 0.0034
# Epoch 15/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0105 - val_loss: 0.0036
# Epoch 16/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0085 - val_loss: 0.0036
# Epoch 17/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0076 - val_loss: 0.0038
# Epoch 18/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0077 - val_loss: 0.0039
# Epoch 19/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0077 - val_loss: 0.0041
# Epoch 20/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0080 - val_loss: 0.0041
# Epoch 21/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0085 - val_loss: 0.0042
# Epoch 22/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0085 - val_loss: 0.0044
# Epoch 23/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0078 - val_loss: 0.0044
# Epoch 24/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0079 - val_loss: 0.0045
# Epoch 25/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0068 - val_loss: 0.0043
# Epoch 26/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - val_loss: 0.0041
# Epoch 27/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - val_loss: 0.0041
# Epoch 28/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - val_loss: 0.0041
# Epoch 29/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0075 - val_loss: 0.0040
# Epoch 30/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0069 - val_loss: 0.0038
# Epoch 31/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - val_loss: 0.0036
# Epoch 32/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0035
# Epoch 33/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0078 - val_loss: 0.0033
# Epoch 34/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0069 - val_loss: 0.0032
# Epoch 35/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0071 - val_loss: 0.0029
# Epoch 36/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - val_loss: 0.0029
# Epoch 37/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0067 - val_loss: 0.0026
# Epoch 38/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - val_loss: 0.0025
# Epoch 39/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0024
# Epoch 40/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0058 - val_loss: 0.0023
# Epoch 41/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 42/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 43/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0020
# Epoch 44/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 45/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 0.0020
# Epoch 46/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - val_loss: 0.0017
# Epoch 47/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0016
# Epoch 48/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0018
# Epoch 49/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0060 - val_loss: 0.0015
# Epoch 50/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0070 - val_loss: 0.0016
# Epoch 51/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0069 - val_loss: 0.0017
# Epoch 52/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0060 - val_loss: 0.0015
# Epoch 53/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0015
# Epoch 54/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0016
# Epoch 55/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0068 - val_loss: 0.0014
# Epoch 56/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 57/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 58/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0068 - val_loss: 0.0013
# Epoch 59/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 60/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0073 - val_loss: 0.0013
# Epoch 61/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 62/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 63/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 64/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 65/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0012
# Epoch 66/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - val_loss: 0.0012
# Epoch 67/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 68/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - val_loss: 0.0014
# Epoch 69/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0013
# Epoch 70/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 71/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0068 - val_loss: 0.0012
# Epoch 72/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 73/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 74/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 75/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0012
# Epoch 76/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0012
# Epoch 77/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0064 - val_loss: 0.0013
# Epoch 78/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0068 - val_loss: 0.0013
# Epoch 79/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 80/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - val_loss: 0.0012
# Epoch 81/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - val_loss: 0.0012
# Epoch 82/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 0.0013
# Epoch 83/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0012
# Epoch 84/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0067 - val_loss: 9.5655e-04
# Epoch 85/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 86/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0064 - val_loss: 0.0014
# Epoch 87/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0073 - val_loss: 0.0011
# Epoch 88/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - val_loss: 0.0013
# Epoch 89/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 90/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 91/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0010
# Epoch 92/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0070 - val_loss: 0.0013
# Epoch 93/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 94/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0070 - val_loss: 0.0011
# Epoch 95/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0013
# Epoch 96/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - val_loss: 0.0015
# Epoch 97/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 98/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0070 - val_loss: 0.0010
# Epoch 99/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 100/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 101/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0066 - val_loss: 0.0011
# Epoch 102/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0057 - val_loss: 0.0012
# Epoch 103/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0069 - val_loss: 0.0010
# Epoch 104/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0055 - val_loss: 0.0012
# Epoch 105/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0077 - val_loss: 0.0013
# Epoch 106/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 107/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 108/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 109/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0013
# Epoch 110/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 111/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 112/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 113/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 0.0013
# Epoch 114/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 115/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - val_loss: 9.6107e-04
# Epoch 116/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0070 - val_loss: 0.0013
# Epoch 117/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0011
# Epoch 118/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0069 - val_loss: 0.0012
# Epoch 119/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 120/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0014
# Epoch 121/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0012
# Epoch 122/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 123/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 0.0013
# Epoch 124/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0010
# Epoch 125/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0012
# Epoch 126/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 127/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 128/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 129/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 130/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - val_loss: 0.0013
# Epoch 131/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - val_loss: 0.0011
# Epoch 132/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 133/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - val_loss: 0.0011
# Epoch 134/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 135/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0012
# Epoch 136/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0014
# Epoch 137/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0014
# Epoch 138/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0064 - val_loss: 0.0011
# Epoch 139/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - val_loss: 0.0011
# Epoch 140/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 141/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 142/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 143/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0064 - val_loss: 0.0013
# Epoch 144/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0012
# Epoch 145/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0064 - val_loss: 0.0012
# Epoch 146/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 147/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 148/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0013
# Epoch 149/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 150/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0069 - val_loss: 0.0013
# Epoch 151/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 152/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 153/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0058 - val_loss: 0.0011
# Epoch 154/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 155/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 156/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 0.0012
# Epoch 157/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0064 - val_loss: 0.0013
# Epoch 158/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 159/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0063 - val_loss: 0.0013
# Epoch 160/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0011
# Epoch 161/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0012
# Epoch 162/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 163/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 164/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0010
# Epoch 165/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 166/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - val_loss: 0.0010
# Epoch 167/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0058 - val_loss: 0.0012
# Epoch 168/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 169/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 170/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 9.1963e-04
# Epoch 171/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 172/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0014
# Epoch 173/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0013
# Epoch 174/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0065 - val_loss: 0.0012
# Epoch 175/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 176/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 177/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0011
# Epoch 178/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 9.2915e-04
# Epoch 179/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 180/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 181/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0013
# Epoch 182/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 183/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 184/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 185/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0064 - val_loss: 0.0012
# Epoch 186/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 187/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 188/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0010
# Epoch 189/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 8.6131e-04
# Epoch 190/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 191/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 192/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0064 - val_loss: 0.0012
# Epoch 193/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0010
# Epoch 194/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0070 - val_loss: 0.0012
# Epoch 195/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0010
# Epoch 196/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0064 - val_loss: 0.0011
# Epoch 197/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 9.7033e-04
# Epoch 198/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0011
# Epoch 199/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0064 - val_loss: 0.0011
# Epoch 200/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0012

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Prepare model location and name
model_location = "..//models//"
model_name = "sony_stock_price_lstm.model.keras"

# Load the best performing model
best_model = load_model(model_location + model_name)

# %%
# Predict stock price for all data splits
y_train_predict = best_model.predict(X_train)
y_validate_predict = best_model.predict(X_validate)
y_test_predict = best_model.predict(X_test)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Restore actual distribution for predicted prices
y_train_inv = sc.inverse_transform(np.concatenate((y_train.reshape(-1,1), np.ones((len(y_train.reshape(-1,1)), 4))), axis=1))[:,0]
y_validate_inv = sc.inverse_transform(np.concatenate((y_validate.reshape(-1,1), np.ones((len(y_validate.reshape(-1,1)), 4))), axis=1))[:,0]
y_test_inv = sc.inverse_transform(np.concatenate((y_test.reshape(-1,1), np.ones((len(y_test.reshape(-1,1)), 4))), axis=1))[:,0]

y_train_predict_inv = sc.inverse_transform(np.concatenate((y_train_predict, np.ones((len(y_train_predict), 4))), axis=1))[:,0]
y_validate_predict_inv = sc.inverse_transform(np.concatenate((y_validate_predict, np.ones((len(y_validate_predict), 4))), axis=1))[:,0]
y_test_predict_inv = sc.inverse_transform(np.concatenate((y_test_predict, np.ones((len(y_test_predict), 4))), axis=1))[:,0]

# %% [markdown]
# #### Display Predictions

# %%
# Define chart colors
train_actual_color = "cornflowerblue"
validate_actual_color = "orange"
test_actual_color = "green"
train_predicted_color = "lightblue"
validate_predicted_color = "peru"
test_predicted_color = "limegreen"

# %%
# Plot actual and predicted price
plt.figure(figsize=(18,6))
plt.plot(df_train_index[sequence_size:,], y_train_inv, label="Training Data", color=train_actual_color)
plt.plot(df_train_index[sequence_size:,], y_train_predict_inv, label="Training Predictions", linewidth=1, color=train_predicted_color)

plt.plot(df_validate_index, y_validate_inv, label="Validation Data", color=validate_actual_color)
plt.plot(df_validate_index, y_validate_predict_inv, label="Validation Predictions", linewidth=1, color=validate_predicted_color)

plt.plot(df_test_index, y_test_inv, label="Testing Data", color=test_actual_color)
plt.plot(df_test_index, y_test_predict_inv, label="Testing Predictions", linewidth=1, color=test_predicted_color)

plt.title("Sony Stock Open Price Predictions With LSTM")
plt.xlabel("Time bar")
plt.ylabel("Price")
plt.legend()
plt.grid(color="lightgray")

# %% [markdown]
# Based on this expanded overview, the model appears to perform very well throughout the observed period, with the predicted trend tends to align closely with actual stock performance across the three training, validation, and testing periods.
#
# To better assess the model's predictions during the validation and testing periods, let's inspect a zoomed-in version of this chart covering the most recent samples.

# %%
# Plot actual and predicted price
plt.figure(figsize=(18,6))

# Plot test data and predictions
plt.plot(df_test_index, y_test_inv, label="Testing Data", color='blue')
plt.plot(df_test_index, y_test_predict_inv, label="Testing Predictions", linewidth=1, color='red')

# Set title and labels
plt.title("Sony Stock Open Price Predictions With LSTM")
plt.xlabel("Time bar")
plt.ylabel("Price")
plt.legend()
plt.grid(color="lightgray")

# Zoom in on the test section (optional)
# Assuming df_test_index is the range you want to zoom in on
plt.xlim(df_test_index[0], df_test_index[-1])  # Set x-axis limits to the test period
# Optionally adjust the y-axis to focus on the test data (you can modify these values to fit your data)
plt.ylim(min(y_test_predict_inv), max(y_test_inv))  # Adjust the y-axis to focus on test data range

plt.show()
